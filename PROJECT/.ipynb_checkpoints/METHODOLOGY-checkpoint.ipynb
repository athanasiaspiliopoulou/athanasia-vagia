# %% [markdown]
# ## METHODOLOGY

# %% [markdown]
# **Σε αυτό το αρχείο αναλύεται όλη η διαδικασία και η μεθοδολογία που ακολουθήθηκε με σκοπό να πραγματοποιηθεί το ρεπορτάζ με τίτλο "Πόσο ελεύθεροι και ασφαλείς είναι άραγε οι δημοσιογράφοι στη Μέση Ανατολή;" το οποίο υπογράφουν οι Αθανασία Σπηλιοπούλου και Βαϊα-Μαρία Τάτα και βασίζεται στα δεδομένα της Committee to Protect Journalists.**

# %% [markdown]
# #### ΣΥΛΛΟΓΗ ΔΕΔΟΜΕΝΩΝ

# %% [markdown]
# - Η συλλογή των δεδομένων έγινε από την ιστοσελίδα της Committee to Protect Journalists.
# - Η συλλογή δεδομένων αφορούσε περιστατικά δημοσιογράφων και εργαζομένων στα ΜΜΕ  που σκοτώθηκαν, φυλακίστηκαν και εξαφανίστηκαν.
# - Για την κάθε κατηγορία δημιουργήθηκε ένα ξεχωριστό dataset.
# - Για τη συλλογή των δεδομένων ακολουθήθηκε η μέθοδος του scraping με Selenium και Beautiful Soup.

# %% [markdown]
# #### ΚΑΘΑΡΙΣΜΟΣ ΔΕΔΟΜΕΝΩΝ

# %% [markdown]
# - Το πρώτο βήμα στον καθαρισμό των δεδομένων ήταν η ενοποίηση όλων των dataset που είχαν δημιουργηθεί κατά τη διάρκεια της συλλογής δεδομένων σε ένα dataset που τα περιελάμβανε όλα.
# - Για τον καθαρισμό των δεδομένων με pandas διορθώθηκαν λάθη που προέκυψαν κατά τη διάρκεια του scraping, αντικαταστάθηκαν όποιες κενές τιμές έπρεπε να αντικατασταθούν και αφαιρέθηκαν στοιχεία που ήταν περιττά για την έρευνα.
# - Ως επιπλέον εργαλείο χρησιμοποιήθηκε η χειροκίνητη διόρθωση στοιχείων με Google Spreadsheets, καθώς ήταν πολύ λίγα και συγκεκριμένα.

# %% [markdown]
# #### ΑΝΑΛΥΣΗ ΔΕΔΟΜΕΝΩΝ

# %% [markdown]
# - Για την ανάλυση των δεδομένων δημιουργήθηκαν νέες στήλες στο dataset, ώστε με βάση τις αρχικές πληροφορίες να υπάρχει η δυνατότητα ποσοτικής ανάλυσης των δεδομένων.
# - Κατά τη διάρκεια της έρευνας αναλύθηκαν όλες οι επιθέσεις στον Τύπο ως σύνολο για τις χώρες της Μέσης Ανατολής και ως ένα διαφορετικό σύνολο για τις υπόλοιπες χώρες του κόσμου, όλες οι επιθέσεις επί μέρους για την κάθε χώρα της Μέσης Ανατολής, τα ποσοστά των ειδών των επιθέσεων στις χώρες της Μέσης Ανατολής, το διαχωρισμό των επιθέσεων στη Μέση Ανατολή με βάση το φύλο και το διαχωρισμό των επιθέσεων στη Μέση Ανατολή με βάση το αν το εκάστοτε περιστατικό είναι εργαζόμενος σε κάποιο μέσο ή freelancer.

# %% [markdown]
# #### ΟΠΤΙΚΟΠΟΙΗΣΗ ΔΕΔΟΜΕΝΩΝ

# %% [markdown]
# - Η οπτικοποίηση των δεδομένων πραγματοποιήθηκε μέσω του Datawrapper.
# - Στην περίπτωση του γραφήματος για τις επιθέσεις επί μέρους για την κάθε χώρα της Μέσης Ανατολής, όπου επιλέχθηκε ένα γράφημα-χάρτης, από το γράφημα απουσιάζει το Αφγανιστάν, καθώς, αν και στην ανάλυσή μας θεωρήθηκε ως χώρα της Μέσης Ανατολής, το format του εν λόγω γραφήματος δεν συμπεριελάμβανε την εν λόγω χώρα. Εμμείναμε στην επιλογή μας αυτή, καθώς τα δεδομένα που χρησιμοποιήθηκαν για αυτή την οπτικοποίηση δεν επηρεάστηκαν από την απουσία των δεδομένων που αφορούν το Αφγανιστάν.
