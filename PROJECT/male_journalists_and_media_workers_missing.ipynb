# %%
#imports
import pandas as pd

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

import time

#set ups
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
url = 'https://cpj.org/data/missing/?status=Missing&gender%5B%5D=Male&start_year=2012&end_year=2022&group_by=location'
driver = webdriver.Chrome()
driver.get(url)

# %%
#create a list of numbers from 1 to 20
numbers = list(range(1,21))

#create an initially empty list
mydata = []

#loop through your genders
#select each one of those and do several other things for each gender in genders

driver.find_element(By.LINK_TEXT, 'Last').click()
    
#get the page numbers that are visible while you are on the last page
page_numbers = driver.find_elements(By.CLASS_NAME, 'page-item')
#define the number of the last page of the table
last_table_page = int(page_numbers[-3].text)

#click on the First page to go back
driver.find_element(By.LINK_TEXT, 'First').click()
    
#define your currently active page 
active_page = int(driver.find_element(By.CSS_SELECTOR, "li.page-item.active").text)
    
    #create a while loop!!!
    #we use while loops when we don't know the exact number of iterations
    #we just know that we want to keep looping through as long as a specific condition is true
    #we hereby wish to do several things while our active page is not the last one
    
    #so, while that happens...
while active_page < last_table_page:
        
        #print your currently active page
    print(f"Page: {active_page}")
        #make your driver sleep for 5'' before it goes on
    time.sleep(5)
    
        #loop through your list of numbers
    for n in numbers:
            
            #create a dictionary called data
        data = {}
            
            #find each different name text
        name = driver.find_element(By.XPATH, f'/html/body/div[1]/div/div/div[2]/div/div[1]/div/table/tbody/tr[{n}]/td[1]/a').text
        organization = driver.find_element(By.XPATH, f'/html/body/div[1]/div/div/div[2]/div/div[1]/div/table/tbody/tr[{n}]/td[2]').text
        date = driver.find_element(By.XPATH, f'/html/body/div[1]/div/div/div[2]/div/div[1]/div/table/tbody/tr[{n}]/td[3]').text
        location = driver.find_element(By.XPATH, f'/html/body/div[1]/div/div/div[2]/div/div[1]/div/table/tbody/tr[{n}]/td[4]').text
            
        data['name'] = name
        data['organization'] = organization
        data['date'] = date
        data['location'] = location
            
            #check them out by printing them
        print(name, organization, date, location)
            
            #append your initially empty list
        mydata.append(data)
            
        #find the "Next" button in your page
    button = driver.find_element(By.LINK_TEXT, "Next")  
        #click "Next"
    button.click()
        
        #redefine your active page
    active_page += 1
        
        #make your driver sleep for 5'' before it goes on
    time.sleep(5)
            
else:
    print(f'Your currently active page is page number {active_page}. This should be the last page. I am getting the data and then I am done.')
        
    #get the data, store them, append your mydata list and that's it
    for n in numbers:
            
        data = {}
            
            #use try-except to avoid errors, especially when in your last page
            #because then most possible scenario is that your script will not find 20 names...
        try:
            name = driver.find_element(By.XPATH, f'/html/body/div[1]/div/div/div[2]/div/div[1]/div/table/tbody/tr[{n}]/td[1]/a').text
            
            data['name'] = name
            data['organization'] = organization
            data['date'] = date
            data['location'] = location

            print(name, organization, date, location)
                
        except:
                #if you fail finding data, just continue instead of breaking (throwing errors)
            continue
            
        mydata.append(data)
# Out:
# Page: 1
# Acquitté Kisembo Agence France-Presse June 26, 2003 Democratic Republic of the Congo
# Ahmed Al-Dulami Al-Sharqiya TV June 1, 2014 Iraq
# Ahmed Rilwan Abdulla Minivan News August 7, 2014 Maldives
# Alfredo Jiménez Mota El Imparcial April 2, 2005 Mexico
# Ali Astamirov Agence France-Presse July 4, 2003 Russia
# Andrei Bazavluk Lita-M August 11, 1996 Russia
# Austin Tice Freelance August 13, 2012 Syria
# Aziz Bouabdallah Al-Alam al-Siyassi April 12, 1997 Algeria
# Azory Gwanda Mwanachi,The Citizen November 21, 2017 Tanzania
# Djamel Eddine Fahassi Alger Chaîne III May 6, 1995 Algeria
# Djuro Slavuj Radio Pristina August 21, 1998 Serbia and Montenegro
# Elyuddin Telaumbanua Berita Sore August 17, 2005 Indonesia
# Emmanuel Munyemanzi Rwandan National Television May 2, 1998 Rwanda
# Farhad Hamo Rudaw TV March 9, 2015 Syria
# Feliks Titov Nevskoye Vremya February 1, 1995 Russia
# Fred Nérac ITV News March 22, 2003 Iraq
# Gerardo Paredes Pérez TV Azteca Noreste May 10, 2007 Mexico
# Guy-André Kieffer Freelance April 16, 2004 Ivory Coast
# Ham Jin Woo Daily NK May 29, 2017 China
# Ibraimo Abú Mbaruco Palma Community Radio April 7, 2020 Mozambique
# Page: 2
# Isam al-Shumari Sudost Media August 15, 2004 Iraq
# Ishzak Ould Mokhtar Sky New Arabia October 15, 2013 Syria
# Jamal Sobhy Al-Mosuliya TV July 1, 2014 Iraq
# Jean Bigirimana Iwacu,Infos Grand Lacs July 22, 2016 Burundi
# Jean-Pascal Couraud Les Nouvelles December 15, 1997 French Polynesia
# John Cantlie Freelance November 22, 2012 Syria
# Jorge Molontzín Centlal Confidencial March 10, 2021 Mexico
# José Antonio García Apac Ecos de la Cuenca en Tepalcatepec November 20, 2006 Mexico
# Jumpei Yasuda Freelance June 23, 2015 Syria
# Kamaran Najm Metrography June 12, 2014 Iraq
# Kazem Akhavan IRNA July 4, 1982 Lebanon
# Maksim Shabalin Nevskoye Vremya February 1, 1995 Russia
# Manasse Mugabo United Nations Assistance Mission in Rwanda Radio August 19, 1995 Rwanda
# Manuel Gabriel Fonseca Hernández El Mañanero September 17, 2011 Mexico
# Marco Antonio López Ortiz Novedades Acapulco June 7, 2011 Mexico
# Miguel Morales Estrada Diario de Poza Rica,Tribuna Papanteca July 19, 2012 Mexico
# Mohamed al-Saeed Syrian State TV July 19, 2012 Syria
# Mohamed Hassaine Alger Républicain March 1, 1994 Algeria
# Mohammed Galal Okasha Al Barqa TV August 1, 2014 Libya
# Muayad Saloum Orient TV November 1, 2013 Syria
# Your currently active page is page number 3. This should be the last page. I am getting the data and then I am done.
# Muhannad al-Okaidi Orient TV November 1, 2013 Syria
# Omar Younis al-Ghaafiqi Orient TV November 1, 2013 Syria
# Pedro Argüello Orient TV November 1, 2013 Syria
# Prageeth Eknelygoda Orient TV November 1, 2013 Syria
# Qais Talal Orient TV November 1, 2013 Syria
# Rafael Ortiz Martínez Orient TV November 1, 2013 Syria
# Ramón Ángeles Zalpa Orient TV November 1, 2013 Syria
# Reda Helal Orient TV November 1, 2013 Syria
# Salvador Adame Pardo Orient TV November 1, 2013 Syria
# Samir Kassab Orient TV November 1, 2013 Syria
# Sergei Ivanov Orient TV November 1, 2013 Syria
# Sergio Landa Rosado Orient TV November 1, 2013 Syria
# Sofiene Chourabi Orient TV November 1, 2013 Syria
# Utpal Das Orient TV November 1, 2013 Syria
# Vasyl Klymentyev Orient TV November 1, 2013 Syria
# Vitaly Shevchenko Orient TV November 1, 2013 Syria
# Vladjimir Legagneur Orient TV November 1, 2013 Syria
# Waheed Mohammed Naji Haider (Waheed al-Sufi) Orient TV November 1, 2013 Syria
# Younis al-Mabrok al-Moghazy Orient TV November 1, 2013 Syria

# %%
df = pd.DataFrame(mydata)
df.shape
df
# Out:
#                                             name  \
# 0                               Acquitté Kisembo
# 1                                Ahmed Al-Dulami
# 2                           Ahmed Rilwan Abdulla
# 3                           Alfredo Jiménez Mota
# 4                                  Ali Astamirov
# 5                                Andrei Bazavluk
# 6                                    Austin Tice
# 7                               Aziz Bouabdallah
# 8                                   Azory Gwanda
# 9                          Djamel Eddine Fahassi
# 10                                  Djuro Slavuj
# 11                          Elyuddin Telaumbanua
# 12                           Emmanuel Munyemanzi
# 13                                   Farhad Hamo
# 14                                  Feliks Titov
# 15                                    Fred Nérac
# 16                         Gerardo Paredes Pérez
# 17                             Guy-André Kieffer
# 18                                   Ham Jin Woo
# 19                           Ibraimo Abú Mbaruco
# 20                               Isam al-Shumari
# 21                           Ishzak Ould Mokhtar
# 22                                   Jamal Sobhy
# 23                               Jean Bigirimana
# 24                           Jean-Pascal Couraud
# 25                                  John Cantlie
# 26                       Jorge Molontzín Centlal
# 27                      José Antonio García Apac
# 28                                 Jumpei Yasuda
# 29                                  Kamaran Najm
# 30                                 Kazem Akhavan
# 31                               Maksim Shabalin
# 32                                Manasse Mugabo
# 33              Manuel Gabriel Fonseca Hernández
# 34                     Marco Antonio López Ortiz
# 35                        Miguel Morales Estrada
# 36                              Mohamed al-Saeed
# 37                              Mohamed Hassaine
# 38                         Mohammed Galal Okasha
# 39                                 Muayad Saloum
# 40                            Muhannad al-Okaidi
# 41                       Omar Younis al-Ghaafiqi
# 42                                Pedro Argüello
# 43                           Prageeth Eknelygoda
# 44                                    Qais Talal
# 45                         Rafael Ortiz Martínez
# 46                           Ramón Ángeles Zalpa
# 47                                    Reda Helal
# 48                          Salvador Adame Pardo
# 49                                  Samir Kassab
# 50                                 Sergei Ivanov
# 51                           Sergio Landa Rosado
# 52                              Sofiene Chourabi
# 53                                     Utpal Das
# 54                              Vasyl Klymentyev
# 55                             Vitaly Shevchenko
# 56                           Vladjimir Legagneur
# 57  Waheed Mohammed Naji Haider (Waheed al-Sufi)
# 58                   Younis al-Mabrok al-Moghazy
#
#                                          organization                date  \
# 0                                Agence France-Presse       June 26, 2003
# 1                                      Al-Sharqiya TV        June 1, 2014
# 2                                        Minivan News      August 7, 2014
# 3                                        El Imparcial       April 2, 2005
# 4                                Agence France-Presse        July 4, 2003
# 5                                              Lita-M     August 11, 1996
# 6                                           Freelance     August 13, 2012
# 7                                  Al-Alam al-Siyassi      April 12, 1997
# 8                                Mwanachi,The Citizen   November 21, 2017
# 9                                    Alger Chaîne III         May 6, 1995
# 10                                     Radio Pristina     August 21, 1998
# 11                                        Berita Sore     August 17, 2005
# 12                        Rwandan National Television         May 2, 1998
# 13                                           Rudaw TV       March 9, 2015
# 14                                    Nevskoye Vremya    February 1, 1995
# 15                                           ITV News      March 22, 2003
# 16                                  TV Azteca Noreste        May 10, 2007
# 17                                          Freelance      April 16, 2004
# 18                                           Daily NK        May 29, 2017
# 19                              Palma Community Radio       April 7, 2020
# 20                                       Sudost Media     August 15, 2004
# 21                                     Sky New Arabia    October 15, 2013
# 22                                     Al-Mosuliya TV        July 1, 2014
# 23                             Iwacu,Infos Grand Lacs       July 22, 2016
# 24                                      Les Nouvelles   December 15, 1997
# 25                                          Freelance   November 22, 2012
# 26                                       Confidencial      March 10, 2021
# 27                  Ecos de la Cuenca en Tepalcatepec   November 20, 2006
# 28                                          Freelance       June 23, 2015
# 29                                        Metrography       June 12, 2014
# 30                                               IRNA        July 4, 1982
# 31                                    Nevskoye Vremya    February 1, 1995
# 32  United Nations Assistance Mission in Rwanda Radio     August 19, 1995
# 33                                        El Mañanero  September 17, 2011
# 34                                 Novedades Acapulco        June 7, 2011
# 35              Diario de Poza Rica,Tribuna Papanteca       July 19, 2012
# 36                                    Syrian State TV       July 19, 2012
# 37                                  Alger Républicain       March 1, 1994
# 38                                        Al Barqa TV      August 1, 2014
# 39                                          Orient TV    November 1, 2013
# 40                                          Orient TV    November 1, 2013
# 41                                          Orient TV    November 1, 2013
# 42                                          Orient TV    November 1, 2013
# 43                                          Orient TV    November 1, 2013
# 44                                          Orient TV    November 1, 2013
# 45                                          Orient TV    November 1, 2013
# 46                                          Orient TV    November 1, 2013
# 47                                          Orient TV    November 1, 2013
# 48                                          Orient TV    November 1, 2013
# 49                                          Orient TV    November 1, 2013
# 50                                          Orient TV    November 1, 2013
# 51                                          Orient TV    November 1, 2013
# 52                                          Orient TV    November 1, 2013
# 53                                          Orient TV    November 1, 2013
# 54                                          Orient TV    November 1, 2013
# 55                                          Orient TV    November 1, 2013
# 56                                          Orient TV    November 1, 2013
# 57                                          Orient TV    November 1, 2013
# 58                                          Orient TV    November 1, 2013
#
#                             location
# 0   Democratic Republic of the Congo
# 1                               Iraq
# 2                           Maldives
# 3                             Mexico
# 4                             Russia
# 5                             Russia
# 6                              Syria
# 7                            Algeria
# 8                           Tanzania
# 9                            Algeria
# 10             Serbia and Montenegro
# 11                         Indonesia
# 12                            Rwanda
# 13                             Syria
# 14                            Russia
# 15                              Iraq
# 16                            Mexico
# 17                       Ivory Coast
# 18                             China
# 19                        Mozambique
# 20                              Iraq
# 21                             Syria
# 22                              Iraq
# 23                           Burundi
# 24                  French Polynesia
# 25                             Syria
# 26                            Mexico
# 27                            Mexico
# 28                             Syria
# 29                              Iraq
# 30                           Lebanon
# 31                            Russia
# 32                            Rwanda
# 33                            Mexico
# 34                            Mexico
# 35                            Mexico
# 36                             Syria
# 37                           Algeria
# 38                             Libya
# 39                             Syria
# 40                             Syria
# 41                             Syria
# 42                             Syria
# 43                             Syria
# 44                             Syria
# 45                             Syria
# 46                             Syria
# 47                             Syria
# 48                             Syria
# 49                             Syria
# 50                             Syria
# 51                             Syria
# 52                             Syria
# 53                             Syria
# 54                             Syria
# 55                             Syria
# 56                             Syria
# 57                             Syria
# 58                             Syria

# %%
df.to_csv('male_journalists_and_media_workers_missing.csv',index=False)

# %%
driver.close()
