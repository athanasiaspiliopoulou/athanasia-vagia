# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
url = 'https://cpj.org/data/killed/?status=Killed&motiveConfirmed%5B%5D=Confirmed&motiveUnconfirmed%5B%5D=Unconfirmed&type%5B%5D=Journalist&start_year=2012&end_year=2022&group_by=year'

# %%
response = requests.get('https://cpj.org/data/killed/?status=Killed&motiveConfirmed%5B%5D=Confirmed&motiveUnconfirmed%5B%5D=Unconfirmed&type%5B%5D=Journalist&start_year=2012&end_year=2022&group_by=year')
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
# 	<script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# 	<script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
# 	<![endif]-->
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v20.5 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Explore CPJ's database of attacks on the press</title>
# <link href="https://cpj.org/" rel="canonical">
# <link href="https://cpj.org/page/2/" rel="next"/>
# <meta content="en_US" property="og:locale">
# <meta content="vi_VN" property="og:locale:alternate"/>
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://cpj.org/data/killed/?status=Killed&motiveConfirmed%5B%5D=Confirmed&motiveUnconfirmed%5B%5D=Unconfirmed&type%5B%5D=Journalist&start_year=2012&end_year=2022&group_by=year')

# %%
from selenium.webdriver.common.by import By
driver.find_element(By.CLASS_NAME,'"page-link">3</')
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 from selenium.webdriver.common.by import By
# ----> 2 driver.find_element(By.CLASS_NAME,'"page-link">3</')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...
